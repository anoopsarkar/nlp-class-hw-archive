# %% [markdown]
# # Homework: Word Alignment

# %% [markdown]
# This is your documentation for the word alignment homework.

# %%
# !python3 default.py > dice.a
# Out:
# Training with Dice's coefficient......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
# !python3 score-alignments.py -i dice.a
# Out:
#   Alignment 0  KEY: ( ) = guessed, * = sure, ? = possible
#   ------
#  |(*)    | 2
#  |   (*) | .
#   ------
#    2  .
#
#   Alignment 1  KEY: ( ) = guessed, * = sure, ? = possible
#   ------
#  |(*)    | 2
#  |   (*) | .
#   ------
#    2  .
#
#   Alignment 2  KEY: ( ) = guessed, * = sure, ? = possible
#   ------------
#  |(*)   ( )    | oh
#  |   (*)       | ,
#  |( )   (*)    | oh
#  |          *  | !
#   ------------
#    o  ,  o  !
#    h     h
#
#   Alignment 3  KEY: ( ) = guessed, * = sure, ? = possible
#   ------------
#  |(*)   ( )    | oh
#  |   (*)       | ,
#  |( )   (*)    | oh
#  |          *  | !
#   ------------
#    o  ,  o  !
#    h     h
#
#   Alignment 4  KEY: ( ) = guessed, * = sure, ? = possible
#   ------------
#  |(*)   ( )    | oh
#  |   (*)       | ,
#  |( )   (*)    | oh
#  |          *  | !
#   ------------
#    o  ,  o  !
#    h     h
#
#   Alignment 5  KEY: ( ) = guessed, * = sure, ? = possible
# ...
